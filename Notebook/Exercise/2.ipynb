# %%
import numpy as np
import pandas as pd

# %%
df1 = pd.DataFrame({"No":['1','2','3','4','5']})
df2 = pd.DataFrame({'No':['0','1','3','5','7','9','11']})

# %%
df2[~df2['No'].isin(df1['No'])]
# Out:
#    No
# 3   7
# 4   9
# 5  11

# %%
for i in df2.values.flatten():
    print(i)
# Out:
# 1
# 3
# 5
# 7
# 9
# 11

# %%
pd.concat([df2,df2])
# Out:
#    No
# 0   0
# 1   1
# 2   3
# 3   5
# 4   7
# 5   9
# 6  11
# 0   0
# 1   1
# 2   3
# 3   5
# 4   7
# 5   9
# 6  11

# %%
new_df  = pd.DataFrame({'Links':[]})

# %%
new_df.shape[0]
# Out:
# 0
