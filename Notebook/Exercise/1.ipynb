# %%
import numpy
import pandas as pd
import json

# %%
df = pd.read_csv(r"C:\Users\M S I\Desktop\Myanmar_Houses_Price_Prediction\Scrapped_Data\dataset.csv")

# %%
len(list(json.loads(df.T.to_json()).values()))
# Out:
# 10720
