# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from floor_transcription import floor_trans #This is for Converting Floor variable

# %%
df = pd.read_csv("dataset.csv")
df.drop_duplicates(inplace = True)

# %%
df.head()
# Out:
#                                      title  \
# 0                 Condo For Sale in Yankin
# 1    Apartment For Sale in Okkalappa South
# 2  House For Sale in Dagon Myothit (North)
# 3                  Land For Sale in Yankin
# 4  House For Sale in Dagon Myothit (North)
#
#                                           undertitle  \
# 0  2 bedroom, 2 bathroom Condo for sale in Yankin...
# 1  2 bedroom, 1 bathroom Apartment for sale in Ok...
# 2  4 bedroom, 4 bathroom Privatehouse for sale in...
# 3                    Land for sale in Yankin, Yangon
# 4  5 bedroom, 7 bathroom Privatehouse for sale in...
#
#                                                price  \
# 0  For Sale                                    \r...
# 1  For Sale                                    \r...
# 2  For Sale                                    \r...
# 3  For Sale                                    \r...
# 4  For Sale                                    \r...
#
#                          address                       date  \
# 0                 Yankin, Yangon  Posted Date : 27 Jan 2026
# 1        Okkalappa South, Yangon  Posted Date : 27 Jan 2026
# 2  Dagon Myothit (North), Yangon  Posted Date : 27 Jan 2026
# 3                 Yankin, Yangon  Posted Date : 27 Jan 2026
# 4  Dagon Myothit (North), Yangon  Posted Date : 27 Jan 2026
#
#                                            key_value  \
# 0  [('Type', 'Condo'), ('Area', '1045 ft<sup>2</s...
# 1  [('Type', 'Apartment'), ('Floor', '3'), ('Area...
# 2  [('Type', 'House'), ('Floor', '2.5'), ('Area',...
# 3  [('Type', 'Land'), ('Area', "105' x 50'"), ('O...
# 4  [('Type', 'House'), ('Floor', '3'), ('Area', "...
#
#                                       propertydetail
# 0  Property Name : #Yankin Royal Thitsar Condo Fo...
# 1  Property Name : #တောင်ဥက္ကလာ ၉ရပ်ကွက် VIP သစ္စ...
# 2  Property Name : #မြောက်ဒဂုံ ၃၈ ရပ်ကွက် ပြည်ထော...
# 3  Property Name : #ဘောက်ထော် ပြည်သာယာလမ်းမအနီး မ...
# 4  Property Name : #မြောက်ဒဂုံ (၄၂)ရပ်ကွက် ဗိုလ်မ...

# %% [markdown]
# ## Converting Key_Value Data

# %%
df['key_value_temp'] = df['key_value'].str.replace("[","").str.replace("]","")

# %%
data = []

for i in df['key_value_temp'].str.split("),",regex = False):
    key = []
    value =[]
    for j in i:
        k = j.split(",")[0].replace("('",'').replace("'",'').strip()
        val = j.split(",")[1].replace("'",'').replace('"','').strip()
        key.append(k)
        value.append(val)
    data.append(dict(zip(key,value)))
key_value_df = pd.DataFrame(data)
    
        
key_value_df_back = key_value_df.copy()

# %% [raw]
# ---------------------Finish converting_key_value--------------

# %%
key_value_df['Type'].value_counts()
# Out:
# Type
# Apartment          3350
# House              2871
# Condo              2678
# Land               1664
# Industrial Zone      53
# Office / Retail      39
# Name: count, dtype: int64

# %%
key_value_df['Type'].isnull().sum()
# Out:
# np.int64(0)

# %% [markdown]
# # Cleaning Area Column
#
# In this column we have three kind of value type:
# - foot square
# - acre
# - x_y(X x Y)
# - after extracting all data i convert it into '0' and deleted

# %%
key_value_df['Area'].unique()
# Out:
# array(['1045 ft<sup>2</sup>', '54 x 18', '60 x 20', ...,
#        '2991 ft<sup>2</sup>', '23 x 65', '7925 ft<sup>2</sup>'],
#       shape=(1463,), dtype=object)

# %%
key_value_df[key_value_df['Area'] == '1045 ft<sup>2</sup>']
# Out:
#            Type                 Area Bed Room Bath Room Ownership  \
# 0         Condo  1045 ft<sup>2</sup>        2         2
# 6980  Apartment  1045 ft<sup>2</sup>        2         2         )
#
#        Furnishing Type Floor Phone Availability Date  \
# 0     Fully Furnished)   NaN   NaN               NaN
# 6980               NaN     3   NaN               NaN
#
#      Aircon conditioner details Room Partition Type Flooring Type  \
# 0                           NaN                 NaN           NaN
# 6980                        NaN                 NaN           NaN
#
#      Water System Type Nearby Amenities
# 0                  NaN              NaN
# 6980               NaN              NaN

# %%
def get_ft(x):
    if "ft" in x:
        return(x)
    else:
        return '0'

def make_ft_zero(x):
        if "ft<sup>2</sup>" in x:
            return('0')
        else:
            return x

# %%
key_value_df['Area_ft'] = key_value_df['Area'].apply(get_ft)

# %%
key_value_df['Area_ft'] = key_value_df['Area_ft'].str.replace('ft<sup>2</sup>',"")

# %%
key_value_df.head()
# Out:
#         Type                 Area Bed Room Bath Room Ownership  \
# 0      Condo  1045 ft<sup>2</sup>        2         2
# 1  Apartment              54 x 18        2         1
# 2      House              60 x 20        4         4
# 3       Land             105 x 50      NaN       NaN         )
# 4      House              60 x 22        5         7         )
#
#     Furnishing Type Floor Phone Availability Date Aircon conditioner details  \
# 0  Fully Furnished)   NaN   NaN               NaN                        NaN
# 1  Fully Furnished)     3   NaN               NaN                        NaN
# 2  Fully Furnished)   2.5   NaN               NaN                        NaN
# 3               NaN   NaN   NaN               NaN                        NaN
# 4               NaN     3   NaN               NaN                        NaN
#
#   Room Partition Type Flooring Type Water System Type Nearby Amenities Area_ft
# 0                 NaN           NaN               NaN              NaN   1045
# 1                 NaN           NaN               NaN              NaN       0
# 2                 NaN           NaN               NaN              NaN       0
# 3                 NaN           NaN               NaN              NaN       0
# 4                 NaN           NaN               NaN              NaN       0

# %%
key_value_df['Area'] = key_value_df['Area'].apply(make_ft_zero)

# %%
key_value_df['x_y'] = key_value_df['Area'].apply(lambda x: x if "x"  in str(x) else '0').str.strip()

# %%
key_value_df['acre']= key_value_df['Area'].apply(lambda x: x if 'acre'  in str(x) else '0').str.strip()

# %%
key_value_df
# Out:
#             Type      Area Bed Room Bath Room Ownership   Furnishing Type  \
# 0          Condo         0        2         2            Fully Furnished)
# 1      Apartment   54 x 18        2         1            Fully Furnished)
# 2          House   60 x 20        4         4            Fully Furnished)
# 3           Land  105 x 50      NaN       NaN         )               NaN
# 4          House   60 x 22        5         7         )               NaN
# ...          ...       ...      ...       ...       ...               ...
# 10650      House         0        7         7     Grant   Fully Furnished
# 10651      House   70 x 90        7         4     Grant   Fully Furnished
# 10652      House   70 x 80      NaN       NaN  Contract  Fully Furnished)
# 10653      House         0        7         7     Grant   Fully Furnished
# 10654      House   40 x 70        6         4     Grant   Fully Furnished
#
#         Floor Phone Availability Date Aircon conditioner details  \
# 0         NaN   NaN               NaN                        NaN
# 1           3   NaN               NaN                        NaN
# 2         2.5   NaN               NaN                        NaN
# 3         NaN   NaN               NaN                        NaN
# 4           3   NaN               NaN                        NaN
# ...       ...   ...               ...                        ...
# 10650    3 RC   NaN      ready to use                        NaN
# 10651     2RC   NaN      ready to use                         14
# 10652     2BN   NaN      ready to use                          -
# 10653  3.5 RC   NaN      ready to use                          -
# 10654     2RC   NaN      ready to use                        NaN
#
#               Room Partition Type     Flooring Type    Water System Type  \
# 0                             NaN               NaN                  NaN
# 1                             NaN               NaN                  NaN
# 2                             NaN               NaN                  NaN
# 3                             NaN               NaN                  NaN
# 4                             NaN               NaN                  NaN
# ...                           ...               ...                  ...
# 10650        Master Bedroom Only)  Parquet Flooring  Groundwater pumping
# 10651  Master and Single Bedroom)  Parquet Flooring  Groundwater pumping
# 10652                         NaN               NaN  Groundwater pumping
# 10653  Master and Single Bedroom)  Parquet Flooring  Groundwater pumping
# 10654  Master and Single Bedroom)  Parquet Flooring  Groundwater pumping
#
#       Nearby Amenities Area_ft       x_y acre
# 0                  NaN   1045          0    0
# 1                  NaN       0   54 x 18    0
# 2                  NaN       0   60 x 20    0
# 3                  NaN       0  105 x 50    0
# 4                  NaN       0   60 x 22    0
# ...                ...     ...       ...  ...
# 10650              NaN   6400          0    0
# 10651              NaN       0   70 x 90    0
# 10652              NaN       0   70 x 80    0
# 10653              NaN   7925          0    0
# 10654              NaN       0   40 x 70    0
#
# [10655 rows x 17 columns]

# %%
def make_x_y_and_acre_zero(x):
    if 'x'  in x:
        return "0"
    elif 'acre' in x:
        return '0'
    else:
        return x

# %%
key_value_df['Area'] = key_value_df['Area'].apply(make_x_y_and_acre_zero)

# %%
key_value_df['Area'].unique()
# Out:
# array(['0'], dtype=object)

# %%
key_value_df.head()
# Out:
#         Type Area Bed Room Bath Room Ownership   Furnishing Type Floor Phone  \
# 0      Condo    0        2         2            Fully Furnished)   NaN   NaN
# 1  Apartment    0        2         1            Fully Furnished)     3   NaN
# 2      House    0        4         4            Fully Furnished)   2.5   NaN
# 3       Land    0      NaN       NaN         )               NaN   NaN   NaN
# 4      House    0        5         7         )               NaN     3   NaN
#
#   Availability Date Aircon conditioner details Room Partition Type  \
# 0               NaN                        NaN                 NaN
# 1               NaN                        NaN                 NaN
# 2               NaN                        NaN                 NaN
# 3               NaN                        NaN                 NaN
# 4               NaN                        NaN                 NaN
#
#   Flooring Type Water System Type Nearby Amenities Area_ft       x_y acre
# 0           NaN               NaN              NaN   1045          0    0
# 1           NaN               NaN              NaN       0   54 x 18    0
# 2           NaN               NaN              NaN       0   60 x 20    0
# 3           NaN               NaN              NaN       0  105 x 50    0
# 4           NaN               NaN              NaN       0   60 x 22    0

# %%
key_value_df.drop(columns = ['Area'] , inplace = True)

# %% [raw]
# ------------------- Area Column Finished-------------

# %% [markdown]
# # Filling '0' to missing values and converting the column (Bed Room)

# %%
key_value_df['Bed Room'].unique()
# Out:
# array(['2', '4', nan, '5', '3', '6', '7', '1', '10', '8', '9'],
#       dtype=object)

# %%
key_value_df
# Out:
#             Type Bed Room Bath Room Ownership   Furnishing Type   Floor Phone  \
# 0          Condo        2         2            Fully Furnished)     NaN   NaN
# 1      Apartment        2         1            Fully Furnished)       3   NaN
# 2          House        4         4            Fully Furnished)     2.5   NaN
# 3           Land      NaN       NaN         )               NaN     NaN   NaN
# 4          House        5         7         )               NaN       3   NaN
# ...          ...      ...       ...       ...               ...     ...   ...
# 10650      House        7         7     Grant   Fully Furnished    3 RC   NaN
# 10651      House        7         4     Grant   Fully Furnished     2RC   NaN
# 10652      House      NaN       NaN  Contract  Fully Furnished)     2BN   NaN
# 10653      House        7         7     Grant   Fully Furnished  3.5 RC   NaN
# 10654      House        6         4     Grant   Fully Furnished     2RC   NaN
#
#       Availability Date Aircon conditioner details  \
# 0                   NaN                        NaN
# 1                   NaN                        NaN
# 2                   NaN                        NaN
# 3                   NaN                        NaN
# 4                   NaN                        NaN
# ...                 ...                        ...
# 10650      ready to use                        NaN
# 10651      ready to use                         14
# 10652      ready to use                          -
# 10653      ready to use                          -
# 10654      ready to use                        NaN
#
#               Room Partition Type     Flooring Type    Water System Type  \
# 0                             NaN               NaN                  NaN
# 1                             NaN               NaN                  NaN
# 2                             NaN               NaN                  NaN
# 3                             NaN               NaN                  NaN
# 4                             NaN               NaN                  NaN
# ...                           ...               ...                  ...
# 10650        Master Bedroom Only)  Parquet Flooring  Groundwater pumping
# 10651  Master and Single Bedroom)  Parquet Flooring  Groundwater pumping
# 10652                         NaN               NaN  Groundwater pumping
# 10653  Master and Single Bedroom)  Parquet Flooring  Groundwater pumping
# 10654  Master and Single Bedroom)  Parquet Flooring  Groundwater pumping
#
#       Nearby Amenities Area_ft       x_y acre
# 0                  NaN   1045          0    0
# 1                  NaN       0   54 x 18    0
# 2                  NaN       0   60 x 20    0
# 3                  NaN       0  105 x 50    0
# 4                  NaN       0   60 x 22    0
# ...                ...     ...       ...  ...
# 10650              NaN   6400          0    0
# 10651              NaN       0   70 x 90    0
# 10652              NaN       0   70 x 80    0
# 10653              NaN   7925          0    0
# 10654              NaN       0   40 x 70    0
#
# [10655 rows x 16 columns]

# %%
key_value_df['Bed Room'].fillna("0",inplace = True)
# Out:
# C:\Users\M S I\AppData\Local\Temp\ipykernel_18952\826100264.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   key_value_df['Bed Room'].fillna("0",inplace = True)

# %%
key_value_df['Bed Room'].value_counts()
# Out:
# Bed Room
# 0     6166
# 2     1538
# 3     1386
# 1      643
# 4      502
# 5      226
# 6      106
# 7       69
# 8        9
# 10       8
# 9        2
# Name: count, dtype: int64

# %%
key_value_df['Bed Room']=key_value_df['Bed Room'].astype(int)

# %% [raw]
# -------- Finish Bed Room --------

# %% [markdown]
# # Bath Room column
#
# - Filling Missing Value to "0"
# - Convert it into int type

# %%
key_value_df['Bath Room'].unique()
# Out:
# array(['2', '1', '4', nan, '7', '3', '5', '6', '10', '9', '8'],
#       dtype=object)

# %%
key_value_df['Bath Room'] = key_value_df['Bath Room'].fillna("0").astype(int)

# %%
key_value_df['Bath Room'].value_counts()
# Out:
# Bath Room
# 0     5741
# 1     1828
# 2     1620
# 3      862
# 4      295
# 5      175
# 6       74
# 7       45
# 8        6
# 9        5
# 10       4
# Name: count, dtype: int64

# %% [raw]
# -------- finish Bath Room ---------

# %% [markdown]
# # Ownership Column
# - there is two values like ("",')') which i have to threat as missing values
# - and some values have "text)" parenthesis at last , Cleaned that as well

# %%
key_value_df['Ownership'].value_counts()
# Out:
# Ownership
# )               8239
#                  974
# Contract         602
# Contract)        578
# Grant)           111
# Grant             97
# Inheritance       26
# Inheritance)      16
# Permit)           10
# Permit             2
# Name: count, dtype: int64

# %%
def remove_half_paren(x):
    if x in ['', ')',np.nan]:
        return '0'
    else :
        return x.replace(")",'')

# %%
key_value_df['Ownership']=key_value_df['Ownership'].apply(remove_half_paren).str.strip()

# %%
key_value_df
# Out:
#             Type  Bed Room  Bath Room Ownership   Furnishing Type   Floor  \
# 0          Condo         2          2         0  Fully Furnished)     NaN
# 1      Apartment         2          1         0  Fully Furnished)       3
# 2          House         4          4         0  Fully Furnished)     2.5
# 3           Land         0          0         0               NaN     NaN
# 4          House         5          7         0               NaN       3
# ...          ...       ...        ...       ...               ...     ...
# 10650      House         7          7     Grant   Fully Furnished    3 RC
# 10651      House         7          4     Grant   Fully Furnished     2RC
# 10652      House         0          0  Contract  Fully Furnished)     2BN
# 10653      House         7          7     Grant   Fully Furnished  3.5 RC
# 10654      House         6          4     Grant   Fully Furnished     2RC
#
#       Phone Availability Date Aircon conditioner details  \
# 0       NaN               NaN                        NaN
# 1       NaN               NaN                        NaN
# 2       NaN               NaN                        NaN
# 3       NaN               NaN                        NaN
# 4       NaN               NaN                        NaN
# ...     ...               ...                        ...
# 10650   NaN      ready to use                        NaN
# 10651   NaN      ready to use                         14
# 10652   NaN      ready to use                          -
# 10653   NaN      ready to use                          -
# 10654   NaN      ready to use                        NaN
#
#               Room Partition Type     Flooring Type    Water System Type  \
# 0                             NaN               NaN                  NaN
# 1                             NaN               NaN                  NaN
# 2                             NaN               NaN                  NaN
# 3                             NaN               NaN                  NaN
# 4                             NaN               NaN                  NaN
# ...                           ...               ...                  ...
# 10650        Master Bedroom Only)  Parquet Flooring  Groundwater pumping
# 10651  Master and Single Bedroom)  Parquet Flooring  Groundwater pumping
# 10652                         NaN               NaN  Groundwater pumping
# 10653  Master and Single Bedroom)  Parquet Flooring  Groundwater pumping
# 10654  Master and Single Bedroom)  Parquet Flooring  Groundwater pumping
#
#       Nearby Amenities Area_ft       x_y acre
# 0                  NaN   1045          0    0
# 1                  NaN       0   54 x 18    0
# 2                  NaN       0   60 x 20    0
# 3                  NaN       0  105 x 50    0
# 4                  NaN       0   60 x 22    0
# ...                ...     ...       ...  ...
# 10650              NaN   6400          0    0
# 10651              NaN       0   70 x 90    0
# 10652              NaN       0   70 x 80    0
# 10653              NaN   7925          0    0
# 10654              NaN       0   40 x 70    0
#
# [10655 rows x 16 columns]

# %% [raw]
#  ---------------------- Finished Ownership ------

# %% [markdown]
# # Furnishing Type
# - Tiled Floor &amp; Walls for Kitchen (I have to do this value to encode , I didn't do it yet)
# - Some values have 'text)' parenthesis one last.

# %%
key_value_df['Furnishing Type'].unique()
# Out:
# array(['Fully Furnished)', nan, 'Fully Furnished',
#        'Tiled Floor &amp; Walls for Kitchen', 'Partially Furnished)',
#        'Not Furnished)', 'Not Furnished', 'Partially Furnished'],
#       dtype=object)

# %%
key_value_df['Furnishing Type'] = key_value_df['Furnishing Type'].apply(remove_half_paren).str.strip()

# %% [raw]
#  ------ Finish Furnishing Type --------

# %% [markdown]
# # Floor

# %%
key_value_df.sample(5)
# Out:
#            Type  Bed Room  Bath Room Ownership Furnishing Type Floor Phone  \
# 9892  Apartment         0          0         0               0     2   NaN
# 2614      Condo         0          0         0               0   NaN   NaN
# 5354  Apartment         2          1         0               0    3F   NaN
# 8169  Apartment         0          0         0               0   NaN   NaN
# 1796  Apartment         2          1         0               0   NaN   NaN
#
#      Availability Date Aircon conditioner details Room Partition Type  \
# 9892               NaN                        NaN                 NaN
# 2614               NaN                        NaN                 NaN
# 5354               NaN                        NaN                 NaN
# 8169               NaN                        NaN                 NaN
# 1796               NaN                        NaN                 NaN
#
#      Flooring Type Water System Type Nearby Amenities Area_ft         x_y acre
# 9892           NaN               NaN              NaN       0     17 x 54    0
# 2614           NaN               NaN              NaN       0     17 x 54    0
# 5354           NaN               NaN              NaN       0     15 x 60    0
# 8169           NaN               NaN              NaN       0  12.50 x 50    0
# 1796           NaN               NaN              NaN       0     18 x 54    0

# %%
key_value_df['Floor'].unique()
# Out:
# array([nan, '3', '2.5', 'နှစ်ထပ်လုံးချင်း၊', '2.RC (အိမ်အသင့်အတင့်)',
#        '2.5.RC နှစ်ထပ်ခွဲလုံးချင်းတိုက်သစ်', '3.RC',
#        '2.5.RC With Basement', '-', '2.RC (တောင်အလှည့်)',
#        '2&amp;frac12;.RC (အသစ်စက်စက်)', '4RC', '၂ ထပ်တိုက်', '2RC',
#        '1st Floor', 'BN', '7th', '5F', '5F(below)', 'ပထမထပ်', '၆လွှာ',
#        '6 လွှာ', '2', 'ဒုတိယထပ်', 'မြေညီထပ်', '၇', '3.RC (Roofslab)',
#        '5th Floor (below ?)', 'Penthouse', '7th Floor', 'High Floor',
#        '၂ထပ်', '၃ထပ်ခွဲ', '4', '5', '1.5RC', '1', 'မြေညီ', 'Middle floor',
#        'တတိယထပ်', '2.5.RC (နှစ်ထပ်ခွဲလုံးချင်းအိမ်)', '2.RC (ထောင့်ခြံ)',
#        '3RC', 'High Floor (over 20th Floor)', 'Ground Floor',
#        '2.RC (အရှေ့အလှည့်)', '2.5.RC (အိမ်ကြီးအိမ်ကောင်း)',
#        '2.RC (အိမ်အသစ်စက်စက်)', '3.RC (အိမ်ကောင်း)',
#        '3.RC (36&amp;#039;&amp;times;46&amp;#039;/5000.Sqft)',
#        '2.5.RC (နှစ်ထပ်ခွဲလုံးချင်း)', '2.RC . 3000.Sqft (မြောက်အလှည့်)',
#        '2&amp;frac12; Storey နှစ်ထပ်ခွဲလုံးချင်းအိမ်', '3.RC (4800.Sqft)',
#        '2.5.RC (နှစ်ထပ်ခွဲလုံးချင်းတိုက်သစ်)', 'High floor',
#        'Building 2 RC', 'Lower floor', 'Building 3 RC', '_', '26',
#        '၅လွှာ', '1BN', '7 F', '1PT', '6F', '6F (below)', '5th Floor',
#        '2nd Floor', 'စတုတ္ထထပ်', '3rd Floor', 'G Floor(attic)', '3F',
#        '1.5BN', '3.RC (တောင်အလှည့်)', '2 nd Floor', 'Lower Floor',
#        '2.RC (အိမ်ကြီးအိမ်ကောင်း)', '1.RC + 2.RC အိမ်နှစ်လုံးပါ',
#        '၂ ထပ်တိုက်ဟောင်း', '1RC', '19 floor', '၇လွှာ', '8F(Penthouse)',
#        '၅လွှာ(တစ်မိုးအောက်)', '2.5RC', '2BN',
#        '3.RC (40&amp;#039; &amp;times; 35&amp;#039;)', '၂ ထပ်တိုက် 2.RC',
#        '3.RC (အိမ်ကြီးအိမ်ကောင်း)', '2 RC', '3 RC', '1F', '4F',
#        'မြေညီ+မှန်ခန်း', 'မြေညီ+ပထမထပ်', '2RCတိုက်သစ် Roof Slab', '1 RC',
#        '2 BN', '၄လွှာ', '2SS', '2.5 RC', 'ဂိုထောင်', '2RC ( ဂိုဒေါင်)',
#        '1 BN', '4RC (8000 Sqft)', '(၃)ထပ် RC နှင့် အမိုး Roof Slab',
#        '4.RC (အိမ်ကောင်း)', '2.RC (အိမ်ကောင်း)', '9th Floor',
#        'မြေညီ+ထပ်ခိုး',
#        '23&amp;#039; &amp;times; 65&amp;#039; အကျယ်ရှိ 4.RC',
#        '2.RC အိမ်မကြီး', '2.RC (4200.Sqft)', '3rd floor', '2nd floor',
#        'ပထမထပ်စစ်စစ်', '၅လွှာ (တစ်မိုးအောတစ်', '33th Floor',
#        'မြေညီထပ်ခိုးပါ', '11th Floor', '6th Floor (below?)',
#        'မြေညီထပ်ခိုးအပြည့်ပါ', '၆လွှာ(အပေါ်တွင် ၂လွှာကျန်)', '2BN + 2BN',
#        '1.5 BN', 'နှစ်ထပ်ခွဲ.RC + နှစ်ထပ် Steel Structure',
#        '2.RC (အရှေ့လှည့်/ထောင့်ခြံ)', '2.RC House )တိုက်သစ်/ထောင့်ခြံ)',
#        '3&amp;frac12;.RC (ထောင့်ခြံတိုက်သစ်)',
#        'Steel Structure 3 ထပ်ခွဲ (12000.Sqft)',
#        '၂ ထပ်တိုက် 2.RC (အိမ်ကောင်း)', '2.RC (အိမ် ကြီးအိမ်ကောင်း)', '6',
#        'First floor', '2.RC (နှစ်ထပ်တိုက်လုံးချင်း)',
#        '3 Storey with Roofslab', '2.RC House', '7', 'GF+ထပ်ခိုး', 'GF',
#        '11', '9Floor', '2F',
#        '3.RC (အသင့်နေ ပြင်ဆင်ပြီး လက်တင်နေရန်အသင့်)', '5th floor',
#        'Ground floor+1 st floor', '4 Floor', '5 Floor', '2Floor',
#        '1st floor', '5floor', 'Ground', 'penthouse',
#        'One Storey တစ်ထပ်လုံးချင်းအိမ်လှလှလေး',
#        'Steel Structure 3 ထပ်ခွဲ', 'အိမ်ဟောင်း တစ်လုံးပါ', '10 F(below)',
#        '1FLOOR', '1 and a half', '၄', '3Floor', '3 Floor', '6 Floor',
#        '5F+6F', '10', 'မြေညီ +ထပ်ခိုး', '6လွှာ', '8 th Floor', '22 Floor',
#        '14th Floor', '6th Floor', '3rc', '2floor', '6  Floor', '4 FIOOR',
#        '1/RC', '7F', '1 Floor', 'မြေညီပထမထပ်', 'တစ်ထပ်အိမ်ပါ', '1 SS',
#        '၄ လွှာ', '၅ လွှာ', '4th', 'တတိယထပိ', 'မြေညီ + ထပ်ခိုး', '6RC',
#        '2BN ပါ', '၃ လွှာ', '8', 'Ground Floor+Attic', '6th floor', '5RC',
#        'မြေညီ / ပထမ / ဒုတိယ/တတိယ / ၆လွှာ', '7th floor', '2RC (2)လုံး',
#        '၂ထပ်အိမ်', '7Floor', '10th floor', '5th floor (above ?)',
#        '4th floor', '3.5RC', '2Rc', '1ထပ်အိမ်',
#        'မြေညီထပ် အပါ်တစ်ထပ် ထပ်ပါ', '12',
#        '2.RC (48&amp;#039; &amp;times; 48&amp;#039; / 4608.Sqft)',
#        '8floor', '2 Storey နှစ်ထပ်လုံးချင်းအိမ်', '2.RC', '2 Floor',
#        '၃ ထပ်ခွဲ', '5 floor(below)', '2.RC ပုံစံတူ နှစ်လုံ', '3floor',
#        '6floor', '5floir', '4floor', '1ထပ်တိုက်', 'ဂိုထောင်နှင့်အိမ်အပါ',
#        '2 လွှာ', '5th floor (below) ?', 'စတုတ္ထထပ် (တစ်မိုးအောက်)',
#        '2ထပ်တိုက်', '၁ထပ်အိပ်', '5 လွှာ', '4 လွှာ', '7လွှာ',
#        '2.RC (၃ လုံး)', '8F', '8 Floor(below)', 'စိတ်ကြိုက်အလွှာစုံ',
#        '4ထပ်', '၁ထပ်', 'မြေညီမှန်ခန်း', '3.5', 'မြေညီထပ်+ထပ်ခိုး',
#        'G Floor', '3RC3ထပ်ခွဲ', '3လွှာ', 'နှစ်ထပ်လုံးချင်း', '၆ လွှာ',
#        '3.RC (5345.Sqft)', '2.RC (1800.Sqft) အိမ်နှစ်လုံး ဆင်တူ', '4လွှာ',
#        '5th Floor ( below ?)', 'အလွှာနိမ့် ( 2ခန်း )', '5လွှာ', '၈လွှာ',
#        '၆လွှာ(တစ်မိုးအောက်)', '5th', '4 RC', '2RC+2RC', '5 RC', '7 Floor',
#        '2ထပ်အိမ်', '2ထပ်', '2.5 Rc', 'မြေညီထပ်5လွှာ', 'GF+မှန်ခန်း',
#        'နှစ်ထပ်အိမ်', '၁', 'Pt', '2ထပ်အဆောင်', '၂ထပ်တိုက်',
#        '2ထပ်အိမ်ကောင်း', '5th floor (below ?)', 'မြေညီထပ်(ထပ်ခိုးပါ)',
#        'စတုတ္ထထပ်(၅လွှာ)', '1 floor', '8 Floor', 'Third', 'စတုတ္ထလွှာ',
#        '8Floor', '2.RC အိမ်ကြီးအိမ်ကောင်း', '9Floor(Penthouse)', '2PT',
#        '၃ထပ်', '3.RC (အရှေ့အလှည့်)', '3.5 RC', '၂ထပ်ခွဲ', 'gf',
#        '1.5RC+1RV', '၄ထပ်', '၂ထပ်ပျဉ်ထောင်', 'မြေညီထပ်+ထပ်ခိုးတဝက်ပါ',
#        '6ထပ်', '20Lfloor', '3.RC (Classic Style တိုက်သစ်)',
#        'တတိယထပ် ( လေးလွှာ )', '2rc', '၈ထပ်', 'ဟောင်ကောင်မြေညီဝမ်းဆက်',
#        'နှစ်ထပ်တိုက်နှစ်လုံး', '3လွှ', 'သုံးထပ်လုံးချင်း', '1st Flor',
#        'မြေညီထပ်ခိုး', '၅လွှာ (တစ်မိုးအောက်)', '4th Floor',
#        '5th Floor (above)', 'High Floor( over 10th floor)',
#        'နှစ်ထပ်တိုက်', 'နှစ်ထပ်ခွဲလုံးချင်း', '2Bn', 'ထောင့်ကွက်',
#        '3.RC (အသစ်စက်စက်)', '7.5RC', '\\u200bမြေညီ', '3 rd Floor',
#        '6 th Floor', '1.5RC ( သိပ်မကောင်း )', '3RC+ဂိုထောင်', '3 floor',
#        '3.5.RC (၃ထပ်ခွဲ.Roofslab)', '1.RC (အိမ်ကောင်း)',
#        '3&amp;frac12;.RC (၃ ထပ်ခွဲ)', '3.RC (Shophouse Style)',
#        'ပျဥ်ထောင်အိမ်', '4 floor', '2RC (တောင်အလှည့်)', '29', 'GF+1F',
#        'Penthous', 'စတုတထပ်', '၂', '21 floor', 'lower floor',
#        'Building 2 and half RC', 'Building 2.5 RC', 'ပထမထထပ်', '1.5PT',
#        'PT', 'ပထပ်စစ်စစ်', 'High Floor( over 15th floor)',
#        '2.RC . 5000.Sqft (အရှေ့အလှည့်)', '17', '5 Floor(above)',
#        '၅-လွှာ (မြေညီအပါ)', 'သုံးထပ်ခွဲလုံးချင်း', '2.RC (Good)',
#        '6th Floor (below)', '24F + 25F', '1 steel structure',
#        'High Floor( over 20th floor)', 'လုံးချင်းအိမ်', '2ထပ်လုံးချင်း',
#        '၆လွာ', '20TH FLOOR', '5F(above)', 'Hight Floor ( over 16 Floor )',
#        '1RC M-3 + 1RC M-4', '8RC', '2 ထပ်ခွဲ', '9', '12th Floor',
#        '5လွှာ အပေါ်တထပ်ကျန်', '5.5RC', 'Penthouses', '20',
#        'Building 1 RC', '(၃)လွှာ', '2RC (4800.Sqft)', '2.RC အိမ်ကောင်း',
#        '5th floor(below)', '&amp;zwnj;၅လွှာ', '1 st floor', 'GD',
#        'Building 3.5 RC', '6th', 'တစ်ထပ်', 'ပထမ', '၃', 'အလွှာနိမ့်',
#        '4.5', '2 ထပ်အုတ်အိမ်', 'Penhouse', 'ဒုတိယ', 'G Floor+1st Floor',
#        '၅+၆ လွှာ', '4.5RC', '၂ ထပ်အိမ်(ခေါင်တွဲ)', 'Warehouse', 'RC',
#        '၂ထပ်လုံးချင်း', 'GF+1st Floor', '2ပျဥ်ထောင်', 'မြေညီထပ်ခိုစ',
#        '7th  Floor(below)', '14', '၂ ထပ်လုံးချင်း',
#        '10th လွှာ (အပေါ်တစ်ထပ်ကျန်)', '5ထပ်', '၈ လွှာ', '၆', '60',
#        '3RCတိုက်တစ်လုံးပါ', 'မြေ', 'River View', '1RC+1PT', '5500',
#        'High Floor(over 20 th Floor)', 'GF+Attic', 'ပျဥ်ထောင်',
#        'GF+Mirror', 'Middle Floor', '၀', '၃ထပ်တိုက်', 'တတိယ',
#        'Mirror floor', '၃.၅', '2RC+3RC', '2RC+Warehouse', '',
#        '1RC + 1 RC', '3.RC (တိုက်သစ်)', '6 Fioor', 'Above 9 Floor',
#        '2RC + 1RC', 'အလွှာမြင့်', '2.RC (Roofslab)', 'နှစ်ထပ်',
#        'ဂိုဒေါင်', 'တစ်ထပ်တိုက်(1-storeyed)', 'GF Floor', '3.5rc',
#        'Above 10 Floor', '3.RC (သုံးထပ်တိုက်)', '8ထပ်',
#        '5လွှာ တစ်မိုးအောက်', 'လေးထပ်ခွဲလုံးချင်း', '2.RC (2) လုံး',
#        'First Floor', '1BN+1BN', '၁ ထပ်ခွဲ', '၃လွှာ', '၅',
#        '2.RC Luxury House', '2.RC Pile Foundation', 'Pehthouse',
#        '2.RC (Luxury House)', '1.5 RC', '6.5 RC', '8 RC',
#        '၃ ထပ်ခွဲ ရှယ်လုံးချင်း'], dtype=object)

# %%
key_value_df[key_value_df['Type']!="Land"]['Floor'].isnull().sum()
# Out:
# np.int64(4343)

# %%
key_value_df[key_value_df['Type']!="Land"]['Floor'].unique()
# Out:
# array([nan, '3', '2.5', 'နှစ်ထပ်လုံးချင်း၊', '2.RC (အိမ်အသင့်အတင့်)',
#        '2.5.RC နှစ်ထပ်ခွဲလုံးချင်းတိုက်သစ်', '3.RC',
#        '2.5.RC With Basement', '-', '2.RC (တောင်အလှည့်)',
#        '2&amp;frac12;.RC (အသစ်စက်စက်)', '4RC', '၂ ထပ်တိုက်', '2RC',
#        '1st Floor', 'BN', '7th', '5F', '5F(below)', 'ပထမထပ်', '၆လွှာ',
#        '6 လွှာ', '2', 'ဒုတိယထပ်', 'မြေညီထပ်', '၇', '3.RC (Roofslab)',
#        '5th Floor (below ?)', 'Penthouse', '7th Floor', 'High Floor',
#        '၂ထပ်', '၃ထပ်ခွဲ', '4', '5', '1.5RC', '1', 'မြေညီ', 'Middle floor',
#        'တတိယထပ်', '2.5.RC (နှစ်ထပ်ခွဲလုံးချင်းအိမ်)', '2.RC (ထောင့်ခြံ)',
#        '3RC', 'High Floor (over 20th Floor)', 'Ground Floor',
#        '2.RC (အရှေ့အလှည့်)', '2.5.RC (အိမ်ကြီးအိမ်ကောင်း)',
#        '2.RC (အိမ်အသစ်စက်စက်)', '3.RC (အိမ်ကောင်း)',
#        '3.RC (36&amp;#039;&amp;times;46&amp;#039;/5000.Sqft)',
#        '2.5.RC (နှစ်ထပ်ခွဲလုံးချင်း)', '2.RC . 3000.Sqft (မြောက်အလှည့်)',
#        '2&amp;frac12; Storey နှစ်ထပ်ခွဲလုံးချင်းအိမ်', '3.RC (4800.Sqft)',
#        '2.5.RC (နှစ်ထပ်ခွဲလုံးချင်းတိုက်သစ်)', 'High floor',
#        'Building 2 RC', 'Lower floor', 'Building 3 RC', '_', '26',
#        '၅လွှာ', '1BN', '7 F', '1PT', '6F', '6F (below)', '5th Floor',
#        '2nd Floor', 'စတုတ္ထထပ်', '3rd Floor', 'G Floor(attic)', '3F',
#        '1.5BN', '3.RC (တောင်အလှည့်)', '2 nd Floor', 'Lower Floor',
#        '2.RC (အိမ်ကြီးအိမ်ကောင်း)', '1.RC + 2.RC အိမ်နှစ်လုံးပါ',
#        '၂ ထပ်တိုက်ဟောင်း', '1RC', '19 floor', '၇လွှာ', '8F(Penthouse)',
#        '၅လွှာ(တစ်မိုးအောက်)', '2.5RC', '2BN',
#        '3.RC (40&amp;#039; &amp;times; 35&amp;#039;)', '၂ ထပ်တိုက် 2.RC',
#        '3.RC (အိမ်ကြီးအိမ်ကောင်း)', '2 RC', '3 RC', '1F', '4F',
#        'မြေညီ+မှန်ခန်း', 'မြေညီ+ပထမထပ်', '2RCတိုက်သစ် Roof Slab', '1 RC',
#        '2 BN', '၄လွှာ', '2SS', '2.5 RC', 'ဂိုထောင်', '2RC ( ဂိုဒေါင်)',
#        '1 BN', '4RC (8000 Sqft)', '(၃)ထပ် RC နှင့် အမိုး Roof Slab',
#        '4.RC (အိမ်ကောင်း)', '2.RC (အိမ်ကောင်း)', '9th Floor',
#        'မြေညီ+ထပ်ခိုး',
#        '23&amp;#039; &amp;times; 65&amp;#039; အကျယ်ရှိ 4.RC',
#        '2.RC အိမ်မကြီး', '2.RC (4200.Sqft)', '3rd floor', '2nd floor',
#        'ပထမထပ်စစ်စစ်', '၅လွှာ (တစ်မိုးအောတစ်', '33th Floor',
#        'မြေညီထပ်ခိုးပါ', '11th Floor', '6th Floor (below?)',
#        'မြေညီထပ်ခိုးအပြည့်ပါ', '၆လွှာ(အပေါ်တွင် ၂လွှာကျန်)', '2BN + 2BN',
#        '1.5 BN', 'နှစ်ထပ်ခွဲ.RC + နှစ်ထပ် Steel Structure',
#        '2.RC (အရှေ့လှည့်/ထောင့်ခြံ)', '2.RC House )တိုက်သစ်/ထောင့်ခြံ)',
#        '3&amp;frac12;.RC (ထောင့်ခြံတိုက်သစ်)',
#        'Steel Structure 3 ထပ်ခွဲ (12000.Sqft)',
#        '၂ ထပ်တိုက် 2.RC (အိမ်ကောင်း)', '2.RC (အိမ် ကြီးအိမ်ကောင်း)', '6',
#        'First floor', '2.RC (နှစ်ထပ်တိုက်လုံးချင်း)',
#        '3 Storey with Roofslab', '2.RC House', '7', 'GF+ထပ်ခိုး', 'GF',
#        '11', '9Floor', '2F',
#        '3.RC (အသင့်နေ ပြင်ဆင်ပြီး လက်တင်နေရန်အသင့်)', '5th floor',
#        'Ground floor+1 st floor', '4 Floor', '5 Floor', '2Floor',
#        '1st floor', '5floor', 'Ground', 'penthouse',
#        'One Storey တစ်ထပ်လုံးချင်းအိမ်လှလှလေး',
#        'Steel Structure 3 ထပ်ခွဲ', 'အိမ်ဟောင်း တစ်လုံးပါ', '10 F(below)',
#        '1FLOOR', '1 and a half', '၄', '3Floor', '3 Floor', '6 Floor',
#        '5F+6F', '10', 'မြေညီ +ထပ်ခိုး', '6လွှာ', '8 th Floor', '22 Floor',
#        '14th Floor', '6th Floor', '3rc', '2floor', '6  Floor', '4 FIOOR',
#        '1/RC', '7F', '1 Floor', 'မြေညီပထမထပ်', 'တစ်ထပ်အိမ်ပါ', '1 SS',
#        '၄ လွှာ', '၅ လွှာ', '4th', 'တတိယထပိ', 'မြေညီ + ထပ်ခိုး', '6RC',
#        '၃ လွှာ', '8', 'Ground Floor+Attic', '6th floor', '5RC',
#        'မြေညီ / ပထမ / ဒုတိယ/တတိယ / ၆လွှာ', '7th floor', '2RC (2)လုံး',
#        '၂ထပ်အိမ်', '7Floor', '10th floor', '5th floor (above ?)',
#        '4th floor', '3.5RC', '2Rc', '1ထပ်အိမ်',
#        'မြေညီထပ် အပါ်တစ်ထပ် ထပ်ပါ', '12',
#        '2.RC (48&amp;#039; &amp;times; 48&amp;#039; / 4608.Sqft)',
#        '8floor', '2 Storey နှစ်ထပ်လုံးချင်းအိမ်', '2.RC', '2 Floor',
#        '၃ ထပ်ခွဲ', '5 floor(below)', '2.RC ပုံစံတူ နှစ်လုံ', '3floor',
#        '6floor', '5floir', '4floor', '1ထပ်တိုက်', 'ဂိုထောင်နှင့်အိမ်အပါ',
#        '2 လွှာ', '5th floor (below) ?', 'စတုတ္ထထပ် (တစ်မိုးအောက်)',
#        '2ထပ်တိုက်', '၁ထပ်အိပ်', '5 လွှာ', '4 လွှာ', '7လွှာ',
#        '2.RC (၃ လုံး)', '8F', '8 Floor(below)', 'စိတ်ကြိုက်အလွှာစုံ',
#        '4ထပ်', '၁ထပ်', 'မြေညီမှန်ခန်း', '3.5', 'မြေညီထပ်+ထပ်ခိုး',
#        'G Floor', '3RC3ထပ်ခွဲ', '3လွှာ', 'နှစ်ထပ်လုံးချင်း', '၆ လွှာ',
#        '3.RC (5345.Sqft)', '2.RC (1800.Sqft) အိမ်နှစ်လုံး ဆင်တူ', '4လွှာ',
#        '5th Floor ( below ?)', 'အလွှာနိမ့် ( 2ခန်း )', '5လွှာ', '၈လွှာ',
#        '၆လွှာ(တစ်မိုးအောက်)', '5th', '4 RC', '5 RC', '7 Floor',
#        '2ထပ်အိမ်', '2ထပ်', '2.5 Rc', 'မြေညီထပ်5လွှာ', 'GF+မှန်ခန်း',
#        'နှစ်ထပ်အိမ်', '၁', 'Pt', '2ထပ်အဆောင်', '၂ထပ်တိုက်',
#        '2ထပ်အိမ်ကောင်း', '5th floor (below ?)', 'မြေညီထပ်(ထပ်ခိုးပါ)',
#        'စတုတ္ထထပ်(၅လွှာ)', '1 floor', '8 Floor', 'Third', 'စတုတ္ထလွှာ',
#        '8Floor', '2.RC အိမ်ကြီးအိမ်ကောင်း', '9Floor(Penthouse)', '2PT',
#        '၃ထပ်', '3.RC (အရှေ့အလှည့်)', '3.5 RC', '၂ထပ်ခွဲ', 'gf',
#        '1.5RC+1RV', '၄ထပ်', '၂ထပ်ပျဉ်ထောင်', 'မြေညီထပ်+ထပ်ခိုးတဝက်ပါ',
#        '6ထပ်', '20Lfloor', '3.RC (Classic Style တိုက်သစ်)',
#        'တတိယထပ် ( လေးလွှာ )', '2rc', '၈ထပ်', 'ဟောင်ကောင်မြေညီဝမ်းဆက်',
#        'နှစ်ထပ်တိုက်နှစ်လုံး', '3လွှ', 'သုံးထပ်လုံးချင်း', '1st Flor',
#        'မြေညီထပ်ခိုး', '၅လွှာ (တစ်မိုးအောက်)', '4th Floor',
#        '5th Floor (above)', 'High Floor( over 10th floor)',
#        'နှစ်ထပ်တိုက်', 'နှစ်ထပ်ခွဲလုံးချင်း', '2Bn', '3.RC (အသစ်စက်စက်)',
#        '7.5RC', '\\u200bမြေညီ', '3 rd Floor', '6 th Floor',
#        '3RC+ဂိုထောင်', '3 floor', '3.5.RC (၃ထပ်ခွဲ.Roofslab)',
#        '1.RC (အိမ်ကောင်း)', '3&amp;frac12;.RC (၃ ထပ်ခွဲ)',
#        '3.RC (Shophouse Style)', 'ပျဥ်ထောင်အိမ်', '4 floor',
#        '2RC (တောင်အလှည့်)', '29', 'GF+1F', 'Penthous', 'စတုတထပ်', '၂',
#        '21 floor', 'lower floor', 'Building 2 and half RC',
#        'Building 2.5 RC', 'ပထမထထပ်', '1.5PT', 'PT', 'ပထပ်စစ်စစ်',
#        'High Floor( over 15th floor)', '2.RC . 5000.Sqft (အရှေ့အလှည့်)',
#        '17', '5 Floor(above)', '၅-လွှာ (မြေညီအပါ)', 'သုံးထပ်ခွဲလုံးချင်း',
#        '2.RC (Good)', '6th Floor (below)', '24F + 25F',
#        '1 steel structure', 'High Floor( over 20th floor)',
#        'လုံးချင်းအိမ်', '2ထပ်လုံးချင်း', '၆လွာ', '20TH FLOOR',
#        '5F(above)', 'Hight Floor ( over 16 Floor )', '1RC M-3 + 1RC M-4',
#        '8RC', '2 ထပ်ခွဲ', '9', '12th Floor', '5လွှာ အပေါ်တထပ်ကျန်',
#        '5.5RC', 'Penthouses', '20', 'Building 1 RC', '(၃)လွှာ',
#        '2RC (4800.Sqft)', '2.RC အိမ်ကောင်း', '5th floor(below)',
#        '&amp;zwnj;၅လွှာ', '1 st floor', 'GD', 'Building 3.5 RC', '6th',
#        'တစ်ထပ်', 'ပထမ', '၃', 'အလွှာနိမ့်', '4.5', '2 ထပ်အုတ်အိမ်',
#        'Penhouse', 'ဒုတိယ', 'G Floor+1st Floor', '၅+၆ လွှာ', '4.5RC',
#        '၂ ထပ်အိမ်(ခေါင်တွဲ)', 'Warehouse', 'RC', '၂ထပ်လုံးချင်း',
#        'GF+1st Floor', '2ပျဥ်ထောင်', 'မြေညီထပ်ခိုစ', '7th  Floor(below)',
#        '14', '၂ ထပ်လုံးချင်း', '10th လွှာ (အပေါ်တစ်ထပ်ကျန်)', '5ထပ်',
#        '၈ လွှာ', '၆', '60', '3RCတိုက်တစ်လုံးပါ', 'River View', '1RC+1PT',
#        '5500', 'High Floor(over 20 th Floor)', 'GF+Attic', 'ပျဥ်ထောင်',
#        'GF+Mirror', 'Middle Floor', '၃ထပ်တိုက်', 'တတိယ', 'Mirror floor',
#        '၃.၅', '2RC+3RC', '2RC+Warehouse', '1RC + 1 RC', '3.RC (တိုက်သစ်)',
#        '6 Fioor', 'Above 9 Floor', '2RC + 1RC', 'အလွှာမြင့်',
#        '2.RC (Roofslab)', 'နှစ်ထပ်', 'ဂိုဒေါင်',
#        'တစ်ထပ်တိုက်(1-storeyed)', 'GF Floor', '3.5rc', 'Above 10 Floor',
#        '3.RC (သုံးထပ်တိုက်)', '8ထပ်', '5လွှာ တစ်မိုးအောက်',
#        'လေးထပ်ခွဲလုံးချင်း', '2.RC (2) လုံး', 'First Floor', '1BN+1BN',
#        '၁ ထပ်ခွဲ', '၃လွှာ', '၅', '2.RC Luxury House',
#        '2.RC Pile Foundation', 'Pehthouse', '2.RC (Luxury House)',
#        '1.5 RC', '6.5 RC', '8 RC', '၃ ထပ်ခွဲ ရှယ်လုံးချင်း'], dtype=object)

# %%
# Transforming Floor Long Text Into Real value , ''
def floor_str_to_int(x):
    key = list(floor_trans.keys())
    value = list(floor_trans.values())
    
    x = str(x).strip()
    if x ==str(np.nan) or x =="":
        return float(0)
        
    elif x in key:
        ind = key.index(x)
        floor = value[ind]
        return float(np.round(floor,1))

# %%
key_value_df['Floor'] = key_value_df['Floor'].apply(floor_str_to_int)

# %%
# sorted(key_value_df['Floor'].value_counts().index)

# %%
key_value_df['Floor'].fillna(float(0.0),inplace = True)
# Out:
# C:\Users\M S I\AppData\Local\Temp\ipykernel_18952\3309058374.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   key_value_df['Floor'].fillna(float(0.0),inplace = True)

# %% [raw]
# -------- Finish Floor ---------

# %% [markdown]
# # Deleting 'Phone' and 'Availibility Date' and 'Aircon conditioner details' Column

# %%
key_value_df['Phone'].value_counts()
# Out:
# Phone
# Yes    99
# Name: count, dtype: int64

# %%
key_value_df.drop(columns = ['Phone'] , inplace = True)

# %% [raw]
# ------- Finish Phone -------

# %%
key_value_df['Availability Date'].unique()
# Out:
# array([nan, 'Ready To Use', '-', 'ready to use', '3.RC (Modernize House)',
#        'Ready to Use', 'Ready to use'], dtype=object)

# %%
key_value_df['Availability Date'].value_counts()
# Out:
# Availability Date
# Ready To Use              87
# ready to use              46
# -                         18
# Ready to use               2
# 3.RC (Modernize House)     1
# Ready to Use               1
# Name: count, dtype: int64

# %%
key_value_df.drop(columns = ['Availability Date'] , inplace = True)

# %% [raw]
# ------- Finish Phone -------

# %%
key_value_df["Aircon conditioner details"].unique()
# Out:
# array([nan, '3', '4', '7', '6', '1', '2', '-', '9', '5', '21', '8', '10',
#        '11', '14'], dtype=object)

# %%
key_value_df["Aircon conditioner details"].isnull().sum()
# Out:
# np.int64(10416)

# %%
key_value_df["Aircon conditioner details"].value_counts()
# Out:
# Aircon conditioner details
# -     104
# 4      44
# 3      33
# 6      13
# 5      10
# 7       9
# 9       8
# 2       8
# 1       2
# 8       2
# 14      2
# 10      2
# 21      1
# 11      1
# Name: count, dtype: int64

# %%
key_value_df.drop(columns = ['Aircon conditioner details'] , inplace = True)

# %% [markdown]
# ------- Finish Aircon conditioner details -------

# %% [markdown]
#  # Room Partition Type

# %%
key_value_df['Room Partition Type'].unique()
# Out:
# array([nan, 'Master and Single Bedroom)', 'Master Bedroom Only)',
#        'Single Bedroom Only)', 'Hall Type)', 'Master Bedroom Only'],
#       dtype=object)

# %%
key_value_df[key_value_df['Type']!='Land']
# Out:
#             Type  Bed Room  Bath Room Ownership  Furnishing Type  Floor  \
# 0          Condo         2          2         0  Fully Furnished    0.0
# 1      Apartment         2          1         0  Fully Furnished    3.0
# 2          House         4          4         0  Fully Furnished    2.5
# 4          House         5          7         0                0    3.0
# 5          House         4          3  Contract                0    0.0
# ...          ...       ...        ...       ...              ...    ...
# 10650      House         7          7     Grant  Fully Furnished    3.0
# 10651      House         7          4     Grant  Fully Furnished    2.0
# 10652      House         0          0  Contract  Fully Furnished    2.0
# 10653      House         7          7     Grant  Fully Furnished    3.5
# 10654      House         6          4     Grant  Fully Furnished    2.0
#
#               Room Partition Type     Flooring Type    Water System Type  \
# 0                             NaN               NaN                  NaN
# 1                             NaN               NaN                  NaN
# 2                             NaN               NaN                  NaN
# 4                             NaN               NaN                  NaN
# 5                             NaN               NaN                  NaN
# ...                           ...               ...                  ...
# 10650        Master Bedroom Only)  Parquet Flooring  Groundwater pumping
# 10651  Master and Single Bedroom)  Parquet Flooring  Groundwater pumping
# 10652                         NaN               NaN  Groundwater pumping
# 10653  Master and Single Bedroom)  Parquet Flooring  Groundwater pumping
# 10654  Master and Single Bedroom)  Parquet Flooring  Groundwater pumping
#
#       Nearby Amenities Area_ft      x_y acre
# 0                  NaN   1045         0    0
# 1                  NaN       0  54 x 18    0
# 2                  NaN       0  60 x 20    0
# 4                  NaN       0  60 x 22    0
# 5                  NaN       0  60 x 70    0
# ...                ...     ...      ...  ...
# 10650              NaN   6400         0    0
# 10651              NaN       0  70 x 90    0
# 10652              NaN       0  70 x 80    0
# 10653              NaN   7925         0    0
# 10654              NaN       0  40 x 70    0
#
# [8991 rows x 13 columns]

# %%
key_value_df['Room Partition Type'].value_counts()
# Out:
# Room Partition Type
# Master and Single Bedroom)    480
# Master Bedroom Only)          159
# Single Bedroom Only)           55
# Hall Type)                     13
# Master Bedroom Only             1
# Name: count, dtype: int64

# %%
key_value_df['Room Partition Type'] = key_value_df['Room Partition Type'].apply(remove_half_paren)

# %% [raw]
# ------finish Room Partition Type-------

# %%
key_value_df
# Out:
#             Type  Bed Room  Bath Room Ownership  Furnishing Type  Floor  \
# 0          Condo         2          2         0  Fully Furnished    0.0
# 1      Apartment         2          1         0  Fully Furnished    3.0
# 2          House         4          4         0  Fully Furnished    2.5
# 3           Land         0          0         0                0    0.0
# 4          House         5          7         0                0    3.0
# ...          ...       ...        ...       ...              ...    ...
# 10650      House         7          7     Grant  Fully Furnished    3.0
# 10651      House         7          4     Grant  Fully Furnished    2.0
# 10652      House         0          0  Contract  Fully Furnished    2.0
# 10653      House         7          7     Grant  Fully Furnished    3.5
# 10654      House         6          4     Grant  Fully Furnished    2.0
#
#              Room Partition Type     Flooring Type    Water System Type  \
# 0                              0               NaN                  NaN
# 1                              0               NaN                  NaN
# 2                              0               NaN                  NaN
# 3                              0               NaN                  NaN
# 4                              0               NaN                  NaN
# ...                          ...               ...                  ...
# 10650        Master Bedroom Only  Parquet Flooring  Groundwater pumping
# 10651  Master and Single Bedroom  Parquet Flooring  Groundwater pumping
# 10652                          0               NaN  Groundwater pumping
# 10653  Master and Single Bedroom  Parquet Flooring  Groundwater pumping
# 10654  Master and Single Bedroom  Parquet Flooring  Groundwater pumping
#
#       Nearby Amenities Area_ft       x_y acre
# 0                  NaN   1045          0    0
# 1                  NaN       0   54 x 18    0
# 2                  NaN       0   60 x 20    0
# 3                  NaN       0  105 x 50    0
# 4                  NaN       0   60 x 22    0
# ...                ...     ...       ...  ...
# 10650              NaN   6400          0    0
# 10651              NaN       0   70 x 90    0
# 10652              NaN       0   70 x 80    0
# 10653              NaN   7925          0    0
# 10654              NaN       0   40 x 70    0
#
# [10655 rows x 13 columns]

# %%
# Finished Till Flooring Type
